# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time

# %%
# Import the requests library.
import requests

# Import the API key.
# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 787

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | acarau
# Processing Record 2 of Set 1 | asau
# Processing Record 3 of Set 1 | mezen
# Processing Record 4 of Set 1 | nanortalik
# Processing Record 5 of Set 1 | bonnyville
# Processing Record 6 of Set 1 | saskylakh
# Processing Record 7 of Set 1 | kayes
# Processing Record 8 of Set 1 | harjavalta
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | inhambane
# Processing Record 12 of Set 1 | almaznyy
# Processing Record 13 of Set 1 | constitucion
# Processing Record 14 of Set 1 | waingapu
# Processing Record 15 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 1 | sturgeon bay
# Processing Record 17 of Set 1 | tiksi
# Processing Record 18 of Set 1 | abu samrah
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | margate
# Processing Record 22 of Set 1 | ahuimanu
# Processing Record 23 of Set 1 | the valley
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | huarmey
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | kansanshi
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | mirnyy
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | sovetskaya gavan
# Processing Record 34 of Set 1 | morena
# Processing Record 35 of Set 1 | cap malheureux
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | ahipara
# Processing Record 41 of Set 1 | puerto ayora
# Processing Record 42 of Set 1 | udalguri
# Processing Record 43 of Set 1 | saint anthony
# Processing Record 44 of Set 1 | lagoa
# Processing Record 45 of Set 1 | adrar
# Processing Record 46 of Set 1 | chumphon
# Processing Record 47 of Set 1 | cherskiy
# Processing Record 48 of Set 1 | shelopugino
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | yumen
# Processing Record 1 of Set 2 | wangaratta
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | clyde river
# Processing Record 5 of Set 2 | shingu
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | mitsamiouli
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | yaan
# Processing Record 10 of Set 2 | meaford
# Processing Record 11 of Set 2 | cariati
# Processing Record 12 of Set 2 | male
# Processing Record 13 of Set 2 | najran
# Processing Record 14 of Set 2 | bilibino
# Processing Record 15 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 2 | eirunepe
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | mahebourg
# Processing Record 19 of Set 2 | biloela
# Processing Record 20 of Set 2 | laguna
# Processing Record 21 of Set 2 | kapaa
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | makakilo city
# Processing Record 26 of Set 2 | kungurtug
# Processing Record 27 of Set 2 | takoradi
# Processing Record 28 of Set 2 | saint-philippe
# Processing Record 29 of Set 2 | san patricio
# Processing Record 30 of Set 2 | sirnak
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | atocha
# Processing Record 33 of Set 2 | kloulklubed
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | svetlogorsk
# Processing Record 36 of Set 2 | katsuura
# Processing Record 37 of Set 2 | taltal
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | faro
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | novikovo
# Processing Record 42 of Set 2 | longkou
# Processing Record 43 of Set 2 | santa elena
# Processing Record 44 of Set 2 | daru
# Processing Record 45 of Set 2 | kununurra
# Processing Record 46 of Set 2 | paso de carrasco
# Processing Record 47 of Set 2 | grand gaube
# Processing Record 48 of Set 2 | lavrentiya
# Processing Record 49 of Set 2 | tongliao
# Processing Record 50 of Set 2 | hegra
# Processing Record 1 of Set 3 | mataura
# Processing Record 2 of Set 3 | port moresby
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | olafsvik
# Processing Record 7 of Set 3 | manbij
# Processing Record 8 of Set 3 | punta arenas
# Processing Record 9 of Set 3 | rikitea
# Processing Record 10 of Set 3 | porto belo
# Processing Record 11 of Set 3 | lata
# Processing Record 12 of Set 3 | fort nelson
# Processing Record 13 of Set 3 | atuona
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | poum
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | biak
# Processing Record 19 of Set 3 | barra do bugres
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | dukat
# Processing Record 22 of Set 3 | naugarzan
# City not found. Skipping...
# Processing Record 23 of Set 3 | kieta
# Processing Record 24 of Set 3 | yerbogachen
# Processing Record 25 of Set 3 | miandrivazo
# Processing Record 26 of Set 3 | ust-koksa
# Processing Record 27 of Set 3 | leningradskiy
# Processing Record 28 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 3 | minab
# Processing Record 30 of Set 3 | coos bay
# Processing Record 31 of Set 3 | martapura
# Processing Record 32 of Set 3 | kinango
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | zeya
# Processing Record 35 of Set 3 | ulaanbaatar
# Processing Record 36 of Set 3 | east london
# Processing Record 37 of Set 3 | raga
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | payakumbuh
# Processing Record 40 of Set 3 | ixtapa
# Processing Record 41 of Set 3 | axim
# Processing Record 42 of Set 3 | neuquen
# Processing Record 43 of Set 3 | kulhudhuffushi
# Processing Record 44 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 3 | san jose del potrero
# Processing Record 46 of Set 3 | nago
# Processing Record 47 of Set 3 | kavaratti
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | guerrero negro
# Processing Record 50 of Set 3 | jaworzno
# Processing Record 1 of Set 4 | aykhal
# Processing Record 2 of Set 4 | avallon
# Processing Record 3 of Set 4 | pacific grove
# Processing Record 4 of Set 4 | manado
# Processing Record 5 of Set 4 | bechem
# Processing Record 6 of Set 4 | faya
# Processing Record 7 of Set 4 | celina
# Processing Record 8 of Set 4 | hobyo
# Processing Record 9 of Set 4 | aras
# Processing Record 10 of Set 4 | nanning
# Processing Record 11 of Set 4 | seoul
# Processing Record 12 of Set 4 | paracuru
# Processing Record 13 of Set 4 | kempele
# Processing Record 14 of Set 4 | portland
# Processing Record 15 of Set 4 | jinxiang
# Processing Record 16 of Set 4 | bluff
# Processing Record 17 of Set 4 | comodoro rivadavia
# Processing Record 18 of Set 4 | samarai
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | los llanos de aridane
# Processing Record 21 of Set 4 | san cristobal
# Processing Record 22 of Set 4 | isangel
# Processing Record 23 of Set 4 | kankan
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | nobres
# Processing Record 26 of Set 4 | manono
# Processing Record 27 of Set 4 | wolnzach
# Processing Record 28 of Set 4 | avarua
# Processing Record 29 of Set 4 | kurchum
# Processing Record 30 of Set 4 | zaraza
# Processing Record 31 of Set 4 | coquimbo
# Processing Record 32 of Set 4 | luderitz
# Processing Record 33 of Set 4 | necochea
# Processing Record 34 of Set 4 | monte azul
# Processing Record 35 of Set 4 | medicine hat
# Processing Record 36 of Set 4 | avera
# Processing Record 37 of Set 4 | touros
# Processing Record 38 of Set 4 | ulladulla
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | kodiak
# Processing Record 41 of Set 4 | alofi
# Processing Record 42 of Set 4 | zhuzhou
# Processing Record 43 of Set 4 | brufut
# Processing Record 44 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | xining
# Processing Record 47 of Set 4 | port macquarie
# Processing Record 48 of Set 4 | tadine
# Processing Record 49 of Set 4 | sabha
# Processing Record 50 of Set 4 | cockburn town
# Processing Record 1 of Set 5 | artyom
# Processing Record 2 of Set 5 | norman wells
# Processing Record 3 of Set 5 | lazaro cardenas
# Processing Record 4 of Set 5 | chuzhou
# Processing Record 5 of Set 5 | mar del plata
# Processing Record 6 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 5 | vestmannaeyjar
# Processing Record 8 of Set 5 | gat
# Processing Record 9 of Set 5 | victoria
# Processing Record 10 of Set 5 | yulara
# Processing Record 11 of Set 5 | sur
# Processing Record 12 of Set 5 | wanaka
# Processing Record 13 of Set 5 | clinton
# Processing Record 14 of Set 5 | jalu
# Processing Record 15 of Set 5 | shakawe
# Processing Record 16 of Set 5 | islampur
# Processing Record 17 of Set 5 | jiangyou
# Processing Record 18 of Set 5 | mtinko
# Processing Record 19 of Set 5 | naze
# Processing Record 20 of Set 5 | zirgan
# Processing Record 21 of Set 5 | tasiilaq
# Processing Record 22 of Set 5 | bredasdorp
# Processing Record 23 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 5 | nome
# Processing Record 25 of Set 5 | semnan
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | ilhabela
# Processing Record 28 of Set 5 | qaqortoq
# Processing Record 29 of Set 5 | terrace bay
# Processing Record 30 of Set 5 | waipawa
# Processing Record 31 of Set 5 | gizo
# Processing Record 32 of Set 5 | road town
# Processing Record 33 of Set 5 | mildura
# Processing Record 34 of Set 5 | cayenne
# Processing Record 35 of Set 5 | mayo
# Processing Record 36 of Set 5 | beoumi
# Processing Record 37 of Set 5 | quatre cocos
# Processing Record 38 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 5 | labuan
# Processing Record 40 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 5 | kushmurun
# Processing Record 42 of Set 5 | richards bay
# Processing Record 43 of Set 5 | natal
# Processing Record 44 of Set 5 | khatanga
# Processing Record 45 of Set 5 | ossora
# Processing Record 46 of Set 5 | neyshabur
# Processing Record 47 of Set 5 | seguin
# Processing Record 48 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 5 | afyonkarahisar
# Processing Record 50 of Set 5 | tuktoyaktuk
# Processing Record 1 of Set 6 | saint-georges
# Processing Record 2 of Set 6 | beringovskiy
# Processing Record 3 of Set 6 | gillette
# Processing Record 4 of Set 6 | fortuna
# Processing Record 5 of Set 6 | zhigansk
# Processing Record 6 of Set 6 | corrientes
# Processing Record 7 of Set 6 | padang
# Processing Record 8 of Set 6 | ketchikan
# Processing Record 9 of Set 6 | manzanillo
# Processing Record 10 of Set 6 | coihaique
# Processing Record 11 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 6 | ushtobe
# Processing Record 13 of Set 6 | havoysund
# Processing Record 14 of Set 6 | mitzic
# Processing Record 15 of Set 6 | lebu
# Processing Record 16 of Set 6 | rio gallegos
# Processing Record 17 of Set 6 | kristinehamn
# Processing Record 18 of Set 6 | sorland
# Processing Record 19 of Set 6 | cabo san lucas
# Processing Record 20 of Set 6 | azar shahr
# City not found. Skipping...
# Processing Record 21 of Set 6 | adre
# Processing Record 22 of Set 6 | kananga
# Processing Record 23 of Set 6 | victor harbor
# Processing Record 24 of Set 6 | srednekolymsk
# Processing Record 25 of Set 6 | vaitape
# Processing Record 26 of Set 6 | lufilufi
# Processing Record 27 of Set 6 | kedrovyy
# Processing Record 28 of Set 6 | ararangua
# Processing Record 29 of Set 6 | upernavik
# Processing Record 30 of Set 6 | leshukonskoye
# Processing Record 31 of Set 6 | zapolyarnyy
# Processing Record 32 of Set 6 | coahuayana
# Processing Record 33 of Set 6 | campbell river
# Processing Record 34 of Set 6 | carauari
# Processing Record 35 of Set 6 | bereda
# Processing Record 36 of Set 6 | nishihara
# Processing Record 37 of Set 6 | menongue
# Processing Record 38 of Set 6 | bubaque
# Processing Record 39 of Set 6 | fonte boa
# Processing Record 40 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 6 | lorica
# Processing Record 42 of Set 6 | la asuncion
# Processing Record 43 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 6 | quime
# Processing Record 45 of Set 6 | wanning
# Processing Record 46 of Set 6 | saint-augustin
# Processing Record 47 of Set 6 | namibe
# Processing Record 48 of Set 6 | fontem
# Processing Record 49 of Set 6 | quarteira
# Processing Record 50 of Set 6 | port lincoln
# Processing Record 1 of Set 7 | bloomingdale
# Processing Record 2 of Set 7 | rosarito
# Processing Record 3 of Set 7 | kavieng
# Processing Record 4 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 7 | kochinda
# Processing Record 6 of Set 7 | ascension
# Processing Record 7 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 7 | moron
# Processing Record 9 of Set 7 | hervey bay
# Processing Record 10 of Set 7 | geraldton
# Processing Record 11 of Set 7 | pangody
# Processing Record 12 of Set 7 | praia
# Processing Record 13 of Set 7 | chimore
# Processing Record 14 of Set 7 | manokwari
# Processing Record 15 of Set 7 | larsnes
# Processing Record 16 of Set 7 | tautira
# Processing Record 17 of Set 7 | yendi
# Processing Record 18 of Set 7 | saldanha
# Processing Record 19 of Set 7 | baiyin
# Processing Record 20 of Set 7 | jubayl
# City not found. Skipping...
# Processing Record 21 of Set 7 | capitao poco
# Processing Record 22 of Set 7 | urengoy
# Processing Record 23 of Set 7 | palu
# Processing Record 24 of Set 7 | dauphin
# Processing Record 25 of Set 7 | rio tercero
# Processing Record 26 of Set 7 | north bend
# Processing Record 27 of Set 7 | kupang
# Processing Record 28 of Set 7 | port hedland
# Processing Record 29 of Set 7 | tarnowskie gory
# Processing Record 30 of Set 7 | salalah
# Processing Record 31 of Set 7 | arethousa
# Processing Record 32 of Set 7 | north platte
# Processing Record 33 of Set 7 | tiruvottiyur
# City not found. Skipping...
# Processing Record 34 of Set 7 | tabuk
# Processing Record 35 of Set 7 | mashhad
# Processing Record 36 of Set 7 | kikwit
# Processing Record 37 of Set 7 | dingle
# Processing Record 38 of Set 7 | bilma
# Processing Record 39 of Set 7 | tilichiki
# Processing Record 40 of Set 7 | maceio
# Processing Record 41 of Set 7 | sioux lookout
# Processing Record 42 of Set 7 | rancho palos verdes
# Processing Record 43 of Set 7 | terrace
# Processing Record 44 of Set 7 | shenjiamen
# Processing Record 45 of Set 7 | banjar
# Processing Record 46 of Set 7 | saint-joseph
# Processing Record 47 of Set 7 | batagay-alyta
# Processing Record 48 of Set 7 | wilkie
# Processing Record 49 of Set 7 | severo-kurilsk
# Processing Record 50 of Set 7 | makuyuni
# Processing Record 1 of Set 8 | nyurba
# Processing Record 2 of Set 8 | kenai
# Processing Record 3 of Set 8 | sechura
# Processing Record 4 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 8 | rawson
# Processing Record 6 of Set 8 | pimentel
# Processing Record 7 of Set 8 | taburao
# City not found. Skipping...
# Processing Record 8 of Set 8 | tromso
# Processing Record 9 of Set 8 | tuatapere
# Processing Record 10 of Set 8 | palmer
# Processing Record 11 of Set 8 | chuy
# Processing Record 12 of Set 8 | mareeba
# Processing Record 13 of Set 8 | mount gambier
# Processing Record 14 of Set 8 | tura
# Processing Record 15 of Set 8 | hofn
# Processing Record 16 of Set 8 | bairiki
# Processing Record 17 of Set 8 | maunabo
# Processing Record 18 of Set 8 | tucuman
# Processing Record 19 of Set 8 | sao joao da barra
# Processing Record 20 of Set 8 | nikolskiy
# Processing Record 21 of Set 8 | edd
# Processing Record 22 of Set 8 | westport
# Processing Record 23 of Set 8 | lishu
# Processing Record 24 of Set 8 | morki
# Processing Record 25 of Set 8 | kruisfontein
# Processing Record 26 of Set 8 | jiancheng
# Processing Record 27 of Set 8 | port-gentil
# Processing Record 28 of Set 8 | fraga
# Processing Record 29 of Set 8 | ewa beach
# Processing Record 30 of Set 8 | zhuanghe
# Processing Record 31 of Set 8 | kilindoni
# Processing Record 32 of Set 8 | soubre
# Processing Record 33 of Set 8 | chulym
# Processing Record 34 of Set 8 | cabiraoan
# Processing Record 35 of Set 8 | dibaya
# City not found. Skipping...
# Processing Record 36 of Set 8 | pedasi
# Processing Record 37 of Set 8 | falkenberg
# Processing Record 38 of Set 8 | sovetskiy
# Processing Record 39 of Set 8 | bonthe
# Processing Record 40 of Set 8 | czersk
# Processing Record 41 of Set 8 | honiara
# Processing Record 42 of Set 8 | haines junction
# Processing Record 43 of Set 8 | baykit
# Processing Record 44 of Set 8 | egvekinot
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | nyzhni sirohozy
# Processing Record 47 of Set 8 | brae
# Processing Record 48 of Set 8 | sandviken
# Processing Record 49 of Set 8 | copiapo
# Processing Record 50 of Set 8 | puerto penasco
# Processing Record 1 of Set 9 | dudinka
# Processing Record 2 of Set 9 | mendi
# Processing Record 3 of Set 9 | la macarena
# Processing Record 4 of Set 9 | sal rei
# Processing Record 5 of Set 9 | tabas
# Processing Record 6 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 9 | ancud
# Processing Record 9 of Set 9 | sao miguel do araguaia
# Processing Record 10 of Set 9 | melito di porto salvo
# Processing Record 11 of Set 9 | grindavik
# Processing Record 12 of Set 9 | kalabo
# Processing Record 13 of Set 9 | hwange
# Processing Record 14 of Set 9 | teshie
# Processing Record 15 of Set 9 | ornskoldsvik
# Processing Record 16 of Set 9 | san quintin
# Processing Record 17 of Set 9 | huilong
# Processing Record 18 of Set 9 | dingzhou
# Processing Record 19 of Set 9 | saint-pierre
# Processing Record 20 of Set 9 | kyra
# Processing Record 21 of Set 9 | kerema
# Processing Record 22 of Set 9 | narsaq
# Processing Record 23 of Set 9 | verkhoyansk
# Processing Record 24 of Set 9 | merauke
# Processing Record 25 of Set 9 | ramshir
# Processing Record 26 of Set 9 | knysna
# Processing Record 27 of Set 9 | alice springs
# Processing Record 28 of Set 9 | dedougou
# Processing Record 29 of Set 9 | gamba
# Processing Record 30 of Set 9 | gorontalo
# Processing Record 31 of Set 9 | la ligua
# Processing Record 32 of Set 9 | moravita
# Processing Record 33 of Set 9 | hamilton
# Processing Record 34 of Set 9 | waspan
# Processing Record 35 of Set 9 | abbeville
# Processing Record 36 of Set 9 | da lat
# Processing Record 37 of Set 9 | burns lake
# Processing Record 38 of Set 9 | vila velha
# Processing Record 39 of Set 9 | marsh harbour
# Processing Record 40 of Set 9 | ilulissat
# Processing Record 41 of Set 9 | linxia
# Processing Record 42 of Set 9 | esperance
# Processing Record 43 of Set 9 | palauig
# Processing Record 44 of Set 9 | pierre
# Processing Record 45 of Set 9 | klaksvik
# Processing Record 46 of Set 9 | huambo
# Processing Record 47 of Set 9 | tyrma
# Processing Record 48 of Set 9 | jizan
# Processing Record 49 of Set 9 | belle glade
# Processing Record 50 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 1 of Set 10 | jalgaon
# Processing Record 2 of Set 10 | sterling
# Processing Record 3 of Set 10 | pambujan
# Processing Record 4 of Set 10 | hambantota
# Processing Record 5 of Set 10 | poronaysk
# Processing Record 6 of Set 10 | paralimni
# Processing Record 7 of Set 10 | russell
# Processing Record 8 of Set 10 | komsomolskiy
# Processing Record 9 of Set 10 | faanui
# Processing Record 10 of Set 10 | san andres
# Processing Record 11 of Set 10 | basco
# Processing Record 12 of Set 10 | booue
# Processing Record 13 of Set 10 | omsukchan
# Processing Record 14 of Set 10 | palana
# Processing Record 15 of Set 10 | leander
# Processing Record 16 of Set 10 | koygorodok
# Processing Record 17 of Set 10 | kattivakkam
# Processing Record 18 of Set 10 | tres arroyos
# Processing Record 19 of Set 10 | bernalillo
# Processing Record 20 of Set 10 | korla
# Processing Record 21 of Set 10 | biltine
# Processing Record 22 of Set 10 | clarence town
# Processing Record 23 of Set 10 | bambous virieux
# Processing Record 24 of Set 10 | wabrzezno
# Processing Record 25 of Set 10 | pavelets
# Processing Record 26 of Set 10 | kiruna
# Processing Record 27 of Set 10 | kabompo
# Processing Record 28 of Set 10 | khandbari
# Processing Record 29 of Set 10 | lebowakgomo
# Processing Record 30 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 10 | mendeleyevsk
# Processing Record 32 of Set 10 | lasa
# Processing Record 33 of Set 10 | bayir
# Processing Record 34 of Set 10 | muros
# Processing Record 35 of Set 10 | cascais
# Processing Record 36 of Set 10 | torbay
# Processing Record 37 of Set 10 | kourou
# Processing Record 38 of Set 10 | quang ngai
# Processing Record 39 of Set 10 | san vicente
# Processing Record 40 of Set 10 | dicabisagan
# Processing Record 41 of Set 10 | ariquemes
# Processing Record 42 of Set 10 | nouadhibou
# Processing Record 43 of Set 10 | pergamino
# Processing Record 44 of Set 10 | magelang
# Processing Record 45 of Set 10 | kirakira
# Processing Record 46 of Set 10 | hoogeveen
# Processing Record 47 of Set 10 | dana point
# Processing Record 48 of Set 10 | rossland
# Processing Record 49 of Set 10 | cairns
# Processing Record 50 of Set 10 | caravelas
# Processing Record 1 of Set 11 | aswan
# Processing Record 2 of Set 11 | greenwood
# Processing Record 3 of Set 11 | mabaruma
# Processing Record 4 of Set 11 | mehamn
# Processing Record 5 of Set 11 | san-pedro
# Processing Record 6 of Set 11 | buta
# Processing Record 7 of Set 11 | truro
# Processing Record 8 of Set 11 | lompoc
# Processing Record 9 of Set 11 | gobabis
# Processing Record 10 of Set 11 | chapais
# Processing Record 11 of Set 11 | iqaluit
# Processing Record 12 of Set 11 | urucara
# Processing Record 13 of Set 11 | saryagash
# Processing Record 14 of Set 11 | zykovo
# Processing Record 15 of Set 11 | leh
# Processing Record 16 of Set 11 | acapulco
# Processing Record 17 of Set 11 | nemuro
# Processing Record 18 of Set 11 | barra do garcas
# Processing Record 19 of Set 11 | sinnamary
# Processing Record 20 of Set 11 | ambon
# Processing Record 21 of Set 11 | port keats
# Processing Record 22 of Set 11 | meulaboh
# Processing Record 23 of Set 11 | puerto maldonado
# Processing Record 24 of Set 11 | hanzhong
# Processing Record 25 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 26 of Set 11 | hinton
# Processing Record 27 of Set 11 | broome
# Processing Record 28 of Set 11 | san pedro
# Processing Record 29 of Set 11 | matagami
# Processing Record 30 of Set 11 | flinders
# Processing Record 31 of Set 11 | aklavik
# Processing Record 32 of Set 11 | vila franca do campo
# Processing Record 33 of Set 11 | suez
# Processing Record 34 of Set 11 | lubbenau
# Processing Record 35 of Set 11 | weinan
# Processing Record 36 of Set 11 | nan
# Processing Record 37 of Set 11 | hameenlinna
# Processing Record 38 of Set 11 | panama city
# Processing Record 39 of Set 11 | arak
# Processing Record 40 of Set 11 | kasongo
# Processing Record 41 of Set 11 | yima
# Processing Record 42 of Set 11 | karratha
# Processing Record 43 of Set 11 | zaragoza
# Processing Record 44 of Set 11 | tayu
# Processing Record 45 of Set 11 | pechenga
# Processing Record 46 of Set 11 | prince rupert
# Processing Record 47 of Set 11 | boden
# Processing Record 48 of Set 11 | kabanjahe
# Processing Record 49 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 11 | iquitos
# Processing Record 1 of Set 12 | lorengau
# Processing Record 2 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 3 of Set 12 | sambava
# Processing Record 4 of Set 12 | santiago del estero
# Processing Record 5 of Set 12 | jibuti
# Processing Record 6 of Set 12 | chake chake
# Processing Record 7 of Set 12 | rettikhovka
# Processing Record 8 of Set 12 | pekan
# Processing Record 9 of Set 12 | mombaca
# Processing Record 10 of Set 12 | san isidro
# Processing Record 11 of Set 12 | lardos
# Processing Record 12 of Set 12 | laurel
# Processing Record 13 of Set 12 | dehri
# Processing Record 14 of Set 12 | novouzensk
# Processing Record 15 of Set 12 | husavik
# Processing Record 16 of Set 12 | harper
# Processing Record 17 of Set 12 | yeppoon
# Processing Record 18 of Set 12 | otane
# Processing Record 19 of Set 12 | pochutla
# Processing Record 20 of Set 12 | puerto rondon
# Processing Record 21 of Set 12 | vysha
# Processing Record 22 of Set 12 | kurumkan
# Processing Record 23 of Set 12 | lima
# Processing Record 24 of Set 12 | salinas
# Processing Record 25 of Set 12 | tiznit
# Processing Record 26 of Set 12 | morehead
# Processing Record 27 of Set 12 | teya
# Processing Record 28 of Set 12 | manaure
# Processing Record 29 of Set 12 | ampanihy
# Processing Record 30 of Set 12 | farafangana
# Processing Record 31 of Set 12 | belyy yar
# Processing Record 32 of Set 12 | opuwo
# Processing Record 33 of Set 12 | mana
# Processing Record 34 of Set 12 | pevek
# Processing Record 35 of Set 12 | egersund
# Processing Record 36 of Set 12 | aguada de pasajeros
# Processing Record 37 of Set 12 | anchorage
# Processing Record 38 of Set 12 | yunjinghong
# City not found. Skipping...
# Processing Record 39 of Set 12 | tres picos
# Processing Record 40 of Set 12 | pontes e lacerda
# Processing Record 41 of Set 12 | roseburg
# Processing Record 42 of Set 12 | altay
# Processing Record 43 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 44 of Set 12 | ponta delgada
# Processing Record 45 of Set 12 | murdochville
# Processing Record 46 of Set 12 | hohhot
# Processing Record 47 of Set 12 | henties bay
# Processing Record 48 of Set 12 | chardara
# Processing Record 49 of Set 12 | brumado
# Processing Record 50 of Set 12 | brownsville
# Processing Record 1 of Set 13 | kango
# Processing Record 2 of Set 13 | sladkovo
# Processing Record 3 of Set 13 | jyvaskyla
# Processing Record 4 of Set 13 | aviles
# Processing Record 5 of Set 13 | vanavara
# Processing Record 6 of Set 13 | oriximina
# Processing Record 7 of Set 13 | kuala terengganu
# Processing Record 8 of Set 13 | lamu
# Processing Record 9 of Set 13 | jacmel
# Processing Record 10 of Set 13 | ust-ilimsk
# Processing Record 11 of Set 13 | kondinskoye
# Processing Record 12 of Set 13 | san policarpo
# Processing Record 13 of Set 13 | camacha
# Processing Record 14 of Set 13 | vila
# Processing Record 15 of Set 13 | berlevag
# Processing Record 16 of Set 13 | mount isa
# Processing Record 17 of Set 13 | areosa
# Processing Record 18 of Set 13 | partizanskoye
# Processing Record 19 of Set 13 | itarema
# Processing Record 20 of Set 13 | celestun
# Processing Record 21 of Set 13 | sakakah
# Processing Record 22 of Set 13 | gushikawa
# Processing Record 23 of Set 13 | trapani
# Processing Record 24 of Set 13 | mogadishu
# Processing Record 25 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 13 | zyryanka
# Processing Record 27 of Set 13 | sembabule
# Processing Record 28 of Set 13 | progreso
# Processing Record 29 of Set 13 | bada
# Processing Record 30 of Set 13 | half moon bay
# Processing Record 31 of Set 13 | chumikan
# Processing Record 32 of Set 13 | kisumu
# Processing Record 33 of Set 13 | fairbanks
# Processing Record 34 of Set 13 | sola
# Processing Record 35 of Set 13 | okhotsk
# Processing Record 36 of Set 13 | aloleng
# Processing Record 37 of Set 13 | mbalmayo
# Processing Record 38 of Set 13 | tubuala
# Processing Record 39 of Set 13 | moranbah
# Processing Record 40 of Set 13 | iroquois falls
# Processing Record 41 of Set 13 | hvolsvollur
# Processing Record 42 of Set 13 | santa luzia
# Processing Record 43 of Set 13 | charters towers
# Processing Record 44 of Set 13 | balkhash
# Processing Record 45 of Set 13 | at-bashi
# Processing Record 46 of Set 13 | aberdeen
# Processing Record 47 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 48 of Set 13 | bonanza
# Processing Record 49 of Set 13 | alekseyevsk
# Processing Record 50 of Set 13 | darab
# Processing Record 1 of Set 14 | kisangani
# Processing Record 2 of Set 14 | maraba
# Processing Record 3 of Set 14 | kashi
# Processing Record 4 of Set 14 | saint-denis
# Processing Record 5 of Set 14 | ler
# Processing Record 6 of Set 14 | caibarien
# Processing Record 7 of Set 14 | huntsville
# Processing Record 8 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 14 | odienne
# Processing Record 10 of Set 14 | kasukabe
# Processing Record 11 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 12 of Set 14 | sao cristovao
# Processing Record 13 of Set 14 | athabasca
# Processing Record 14 of Set 14 | narasannapeta
# Processing Record 15 of Set 14 | kidal
# Processing Record 16 of Set 14 | nylstroom
# City not found. Skipping...
# Processing Record 17 of Set 14 | kropotkin
# Processing Record 18 of Set 14 | alassio
# Processing Record 19 of Set 14 | atasu
# Processing Record 20 of Set 14 | serebryansk
# Processing Record 21 of Set 14 | koumac
# Processing Record 22 of Set 14 | fenyi
# Processing Record 23 of Set 14 | sonamura
# Processing Record 24 of Set 14 | klyuchi
# Processing Record 25 of Set 14 | naifaru
# Processing Record 26 of Set 14 | bogo
# Processing Record 27 of Set 14 | wheeling
# Processing Record 28 of Set 14 | witbank
# Processing Record 29 of Set 14 | bulanash
# Processing Record 30 of Set 14 | dwarka
# Processing Record 31 of Set 14 | port hardy
# Processing Record 32 of Set 14 | bo rai
# Processing Record 33 of Set 14 | nizwa
# Processing Record 34 of Set 14 | boende
# Processing Record 35 of Set 14 | vanimo
# Processing Record 36 of Set 14 | loa janan
# Processing Record 37 of Set 14 | zlynka
# Processing Record 38 of Set 14 | pimenta bueno
# Processing Record 39 of Set 14 | kralendijk
# Processing Record 40 of Set 14 | santa ana
# Processing Record 41 of Set 14 | nandura
# Processing Record 42 of Set 14 | aasiaat
# Processing Record 43 of Set 14 | townsville
# Processing Record 44 of Set 14 | gbadolite
# Processing Record 45 of Set 14 | belmonte
# Processing Record 46 of Set 14 | burnie
# Processing Record 47 of Set 14 | lewiston
# Processing Record 48 of Set 14 | nacala
# Processing Record 49 of Set 14 | inuvik
# Processing Record 50 of Set 14 | honolulu
# Processing Record 1 of Set 15 | uvira
# Processing Record 2 of Set 15 | bivolari
# Processing Record 3 of Set 15 | le port
# Processing Record 4 of Set 15 | kaseda
# Processing Record 5 of Set 15 | williams lake
# Processing Record 6 of Set 15 | kijang
# Processing Record 7 of Set 15 | grand-santi
# Processing Record 8 of Set 15 | lamar
# Processing Record 9 of Set 15 | ourossogui
# Processing Record 10 of Set 15 | te anau
# Processing Record 11 of Set 15 | sigayevo
# Processing Record 12 of Set 15 | kpandae
# Processing Record 13 of Set 15 | troutdale
# Processing Record 14 of Set 15 | moussoro
# Processing Record 15 of Set 15 | skibbereen
# Processing Record 16 of Set 15 | goldap
# Processing Record 17 of Set 15 | mercedes
# Processing Record 18 of Set 15 | jaffna
# Processing Record 19 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 20 of Set 15 | perth
# Processing Record 21 of Set 15 | omboue
# Processing Record 22 of Set 15 | yinchuan
# Processing Record 23 of Set 15 | karaton
# Processing Record 24 of Set 15 | kushiro
# Processing Record 25 of Set 15 | andros town
# Processing Record 26 of Set 15 | san roque
# Processing Record 27 of Set 15 | moose factory
# Processing Record 28 of Set 15 | sourpi
# Processing Record 29 of Set 15 | akdepe
# Processing Record 30 of Set 15 | misratah
# Processing Record 31 of Set 15 | porto novo
# Processing Record 32 of Set 15 | khao yoi
# Processing Record 33 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 15 | yantai
# Processing Record 35 of Set 15 | noyabrsk
# Processing Record 36 of Set 15 | kozan
# Processing Record 37 of Set 15 | durango
# Processing Record 38 of Set 15 | jasper
# Processing Record 39 of Set 15 | mtimbira
# Processing Record 40 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 41 of Set 15 | codrington
# Processing Record 42 of Set 15 | usta muhammad
# Processing Record 43 of Set 15 | bull savanna
# Processing Record 44 of Set 15 | owando
# Processing Record 45 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 46 of Set 15 | riachao das neves
# Processing Record 47 of Set 15 | port blair
# Processing Record 48 of Set 15 | odesskoye
# Processing Record 49 of Set 15 | takhtamygda
# Processing Record 50 of Set 15 | souillac
# Processing Record 1 of Set 16 | ascoli piceno
# Processing Record 2 of Set 16 | muzaffarabad
# Processing Record 3 of Set 16 | soyo
# Processing Record 4 of Set 16 | solenzo
# Processing Record 5 of Set 16 | praya
# Processing Record 6 of Set 16 | mattru
# Processing Record 7 of Set 16 | valparaiso
# Processing Record 8 of Set 16 | tezu
# Processing Record 9 of Set 16 | kahului
# Processing Record 10 of Set 16 | tinskoy
# Processing Record 11 of Set 16 | tevriz
# Processing Record 12 of Set 16 | ambulu
# Processing Record 13 of Set 16 | pisco
# Processing Record 14 of Set 16 | gunjur
# Processing Record 15 of Set 16 | vardo
# Processing Record 16 of Set 16 | dunedin
# Processing Record 17 of Set 16 | saquarema
# Processing Record 18 of Set 16 | jiroft
# City not found. Skipping...
# Processing Record 19 of Set 16 | buritica
# Processing Record 20 of Set 16 | sobolevo
# Processing Record 21 of Set 16 | yunyang
# Processing Record 22 of Set 16 | garmsar
# Processing Record 23 of Set 16 | rosetta
# Processing Record 24 of Set 16 | nanyang
# Processing Record 25 of Set 16 | vetluzhskiy
# Processing Record 26 of Set 16 | bathsheba
# Processing Record 27 of Set 16 | estevan
# Processing Record 28 of Set 16 | makasar
# Processing Record 29 of Set 16 | karpokhorion
# Processing Record 30 of Set 16 | vila do maio
# Processing Record 31 of Set 16 | sitka
# Processing Record 32 of Set 16 | prainha
# Processing Record 33 of Set 16 | segou
# Processing Record 34 of Set 16 | banda aceh
# Processing Record 35 of Set 16 | piacabucu
# Processing Record 36 of Set 16 | wakkanai
# Processing Record 37 of Set 16 | linhares
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Acarau      BR  -2.8856  -40.1200     82.92        71          27
# 1        Asau      RO  46.4333   26.4000     36.95        87          98
# 2       Mezen      RU  65.8522   44.2400      9.75        89         100
# 3  Nanortalik      GL  60.1432  -45.2371     11.75        62          49
# 4  Bonnyville      CA  54.2668 -110.7350     14.18        89         100
# 5   Saskylakh      RU  71.9167  114.0833    -25.74       100          98
# 6       Kayes      ML  14.0000  -11.0000     87.84         7           0
# 7  Harjavalta      FI  61.3167   22.1333     30.58        97          14
# 8       Vaini      TO -21.2000 -175.2000     77.16        94         100
# 9  Chokurdakh      RU  70.6333  147.9167    -30.15       100         100
#
#    Wind Speed Current Description
# 0       15.46          light rain
# 1        1.70     overcast clouds
# 2       12.82     overcast clouds
# 3       20.42    scattered clouds
# 4        9.84     overcast clouds
# 5        3.20     overcast clouds
# 6        8.14           clear sky
# 7        4.52          few clouds
# 8        8.05          light rain
# 9        1.52     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "C:/Users/m143795/Desktop/Class/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
